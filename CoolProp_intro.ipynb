# %% [markdown]
# **The very first introduction to CoolProp**
#
# Instalación de biblioteca CoolProp y cálculo de propiedades.

# %% [markdown]
# Primero, debemos instalar la biblioteca....

# %%
pip install CoolProp
# Out:
# Collecting CoolProp
#   Downloading CoolProp-6.4.1-cp37-cp37m-manylinux1_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.3 MB/s
# Installing collected packages: CoolProp
# Successfully installed CoolProp-6.4.1

# %% [markdown]
# Luego la importamos.....

# %%
import CoolProp.CoolProp as cp

# %% [markdown]
# Para este ejemplo trabajaremos con Agua.
#
# Definiremos como Temperatura de referencia 298 K y Presión de referenica 1 atmósfera: 101,325 kPa

# %%
fluid = "water"
ref_temp = 298
ref_press = 101325

# %% [markdown]
# Calculemos la densidad del agua a la Temperatura y presión de referencia:

# %%
density = cp.PropsSI("D", "T", ref_temp, "P", ref_press, fluid)
density
# Out:
# 0.8856149886576221

# %% [markdown]
# .... ¿En qué unidades está la magnitud que entrega CoolProp?
#
#
# Y podríamos pedirle que evalue la fase en la que se encuentra el agua

# %%
phase = cp.PhaseSI("T", ref_temp, "P", ref_press, fluid)
phase
# Out:
# 'gas'
